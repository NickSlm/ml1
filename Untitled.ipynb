# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
# Out:
# 2024-04-24 14:56:42.767012: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-24 14:56:43.295866: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-24 14:56:43.296011: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-24 14:56:43.396021: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-24 14:56:43.620638: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %%
label_names = {0: "airplane", 1: "automobile", 2: "bird", 3: "cat", 4: "deer", 5: "dog", 
              6: "frog", 7: "horse", 8: "ship", 9: "truck"}

# %%
val_size = x_test.shape[0] // 2

x_train = x_train / 255.
x_val = x_test[:val_size] / 255.
y_val = y_test[:val_size]
x_test = x_test[val_size:] / 255.
y_test = y_test[val_size:]

# %%
def plot_images(images, n_cols):
    n_images = len(images)
    n_rows = n_images // n_cols + 1
    figure = plt.figure(figsize=(2.28, 1.6))
    for i, image in enumerate(images):
        figure.add_subplot(n_rows, n_cols, i + 1)
        plt.imshow(image, cmap="binary")
        plt.axis("off")
    plt.show()

# %%
plot_images(x_test[:8], n_cols=4)

# %%
encoder = keras.models.Sequential([
    keras.layers.Input(shape=[32,32,3]),
    keras.layers.GaussianNoise(0.1),
    keras.layers.Conv2D(filters=16, kernel_size=5, padding="same", activation="selu"),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=32, kernel_size=3, padding="same", activation="selu"),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=64, kernel_size=3, padding="same", activation="selu"),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=128, kernel_size=3, padding="same", activation="selu"),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=256, kernel_size=3, padding="same", activation="selu"),
    keras.layers.MaxPool2D(pool_size=(2,2))
])

decoder = keras.models.Sequential([
    keras.layers.Input(shape=[1,1,256]),
    keras.layers.Conv2DTranspose(128, kernel_size=5, strides=(2, 2), padding='same', activation="selu"),
    keras.layers.Conv2DTranspose(64, kernel_size=5, strides=(2, 2), padding='same', activation="selu"),
    keras.layers.Conv2DTranspose(32, kernel_size=5, strides=(2, 2), padding='same', activation="selu"),
    keras.layers.Conv2DTranspose(16, kernel_size=5, strides=(2, 2), padding='same', activation="selu"),
    keras.layers.Conv2DTranspose(3, kernel_size=5, strides=(2, 2), padding='same', activation="sigmoid"),
])
# Out:
# 2024-04-24 14:56:56.153098: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:06:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-24 14:56:56.788353: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
autoencoder = keras.models.Sequential([encoder, decoder])
autoencoder.compile(loss="binary_crossentropy", optimizer=keras.optimizers.SGD(learning_rate=1.0), metrics=["mse"])

# %%
history = autoencoder.fit(x_train, x_train, epochs=20, validation_data=(x_val, x_val))
# Out:
# 2024-04-24 14:56:59.260447: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 614400000 exceeds 10% of free system memory.
# Epoch 1/20
# 2024-04-24 14:57:00.332631: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 614400000 exceeds 10% of free system memory.
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.6378 - mse: 0.0381 - val_loss: 0.6073 - val_mse: 0.0237
# Epoch 2/20
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.5947 - mse: 0.0189 - val_loss: 0.5955 - val_mse: 0.0190
# Epoch 3/20
# 1563/1563 [==============================] - 46s 30ms/step - loss: 0.5864 - mse: 0.0155 - val_loss: 0.5834 - val_mse: 0.0138
# Epoch 4/20
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5825 - mse: 0.0140 - val_loss: 0.5853 - val_mse: 0.0146
# Epoch 5/20
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5798 - mse: 0.0129 - val_loss: 0.5804 - val_mse: 0.0127
# ...

# %%
n_images = x_test[:8]
n_images_noisy = n_images + np.random.randn(8, 32,32,3) * 0.1
n_images_denoised = autoencoder.predict(n_images_noisy)

figure = plt.figure(figsize=(3, 8))
for i in range(8):
    # original image
    figure.add_subplot(8, 3, i * 3 + 1)
    plt.imshow(n_images[i])
    plt.axis("off")
    # denoised image
    figure.add_subplot(8, 3, i * 3 + 2)
    plt.imshow(n_images_noisy[i])
    plt.axis("off")
    # reconstructed image
    figure.add_subplot(8, 3, i * 3 + 3)
    plt.imshow(n_images_denoised[i])
    plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 172ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
autoencoder.save("my_autoencoder.h5")
# Out:
# /home/nick/miniconda3/envs/tf_env/lib/python3.9/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
n_autoencoder = keras.models.load_model("my_autoencoder.h5")
n_autoencoder_clone = keras.models.clone_model(n_autoencoder)

# %%
classification_model, _ = n_autoencoder.layers

# %%
classification_model.add(keras.layers.Flatten())
classification_model.add(keras.layers.Dense(10, activation="softmax"))
